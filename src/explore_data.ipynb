# %% [markdown]
# # Explore Data

# %% [markdown]
# ## Import libraries

# %%
from utils.constants import DATA_PATH
from utils.enums import RetrieveDataType
from data_retriever.data_retriever import DataRetriever
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
data_retriever = DataRetriever(base_directory=DATA_PATH)
train_data_original = data_retriever.get_data(retrieve_data_type=RetrieveDataType.TRAIN_ORIGINAL)
test_data_original = data_retriever.get_data(retrieve_data_type=RetrieveDataType.TEST_ORIGINAL)

# %%
for i in range(50):
    image = train_data_original[i][0]
    plt.imshow(image)
    plt.axis('off')
    plt.show()
